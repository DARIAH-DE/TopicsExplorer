# 1   0.001669  0.209302  0.142925  0.075225  0.004755  0.004440
# 2   0.001094  0.013398  0.170622  0.079974  0.003039  0.002894
# 3   0.001852  0.016737  0.179948  0.068151  0.004062  0.004127
# 4   0.006620  0.007251  0.041299  0.006620  0.001576  0.005359
# 5   0.004358  0.005069  0.053273  0.011117  0.000445  0.000978
# 6   0.008557  0.003333  0.056837  0.010178  0.002072  0.001531
# 7   0.019323  0.001387  0.057045  0.014885  0.001757  0.001387
# 8   0.006847  0.003841  0.136774  0.026887  0.003173  0.002505
# 9   0.001192  0.001679  0.164858  0.005086  0.002798  0.000900
# 10  0.000437  0.001946  0.139414  0.016320  0.515208  0.003693
# 11  0.338797  0.000732  0.068139  0.046193  0.001002  0.007180
# 12  0.007306  0.009981  0.070694  0.044762  0.003396  0.006894
# 13  0.000516  0.001204  0.022953  0.203889  0.000241  0.410977
# 14  0.017857  0.023268  0.126082  0.110931  0.005952  0.013528
# 15  0.004442  0.007404  0.082428  0.066634  0.009378  0.034057
# 16  0.004795  0.005562  0.075758  0.191983  0.004028  0.076908

# %%
topics_keys = mal.pd.DataFrame(mal.show_topics_keys(output_folder, "topic_keys"))
topics_keys
# Out:
#           0         1         2         3          4          5            6   \
# 0   spurstow    hummil       don        ll        man      sleep           ve
# 1      blood      arms       red       lay       blue       feet        great
# 2       eyes     stood      dark    turned       hand       fear         rose
# 3      small  treasure    sholto   morstan     holmes         mr        night
# 4        sir      moor     henry    holmes     watson         dr  baskerville
# 5        man    holmes      face      door       room      house       window
# 6      conan      door      girl     black        man     olivia        sword
# 7      great     found      make       men      doubt    strange       moment
# 8      world      feet     years     place       long       left        thing
# 9        man      head      long     night       back      heard         knew
# 10   general       sun     space     force      earth   distance        point
# 11      open    horror     death     light      walls       felt         wall
# 12     house    street     uncle    letter      dupin     harris      prefect
# 13    mowgli    jungle  bagheera      wolf        big        nag        rikki
# 14      lake      camp      city      land   danforth        ice    mountains
# 15  answered      hope   drebber   ferrier   lestrade  companion         john
# 16      time      made      good       day       back     looked         side
# 17    matter     point      case   thought       find      words         fact
# 18   ravager       dog  smallest     moore   slippers     master       proper
# 19     atoms    centre      idea  universe  principle        law     tendency
#
#             7        8          9           10          11           12  \
# 0         face  mottram    lowndes        poor        give          isn
# 1         hair    white      trees       sleep         sea          men
# 2        sound     room         ll        knew        body          dog
# 3         miss    jones   answered         mrs    thaddeus       wooden
# 4          man  charles  stapleton    mortimer        hall        hound
# 5         hand     case     street    sherlock      fellow       friend
# 6    cimmerian     head       aram        back      cliffs        hands
# 7          lay     kind       line       large        pass        table
# 8      unknown   things        age       floor     curious       ground
# 9         feet    water       make         sat         don          run
# 10        form  account       time    material        laws  irradiation
# 11      figure     half    windows     brought         mad        night
# 12     shunned  replied   minister         odd      cellar         form
# 13       tikki     thou      baloo         sea       shere         khan
# 14   antarctic     vast       made       range  sculptures          sea
# 15  stangerson    asked    gregson        ring          mr    jefferson
# 16        life    round      place        half       black          put
# 17       thing     long   question      reason      things         mind
# 18      wented     tags       dash        hunt      things         toby
# 19    absolute    stars     system  hypothesis       truth    condition
#
#            13          14         15           16          17         18  \
# 0      pretty     weather      table          die        chap        men
# 1       cried       naked       iron         face    answered       fell
# 2       short         low     caught        sight      struck     broken
# 3     brother      launch      river        smith       major       toby
# 4       night   barrymore         mr        death      london       wife
# 5        part       asked      cried        paper        mind      woman
# 6         men       human       wall        ruins     fingers  khosatral
# 7       wrong   knowledge       gave      mystery       fresh      story
# 8     ancient       forms      stone         part         ago   mountain
# 9         ran      ground      horse        thing       house      young
# 10     action        star   clusters       bodies  conception   original
# 11       grew      rising      heavy       passed    corridor       foot
# 12  continued      family       hill  amontillado      french   document
# 13     toomai         men  elephants       kotick        thee       till
# 14       wind   specimens       snow        abyss     hundred      peaks
# 15   appeared       cried   daughter        death       blood       lucy
# 16       give        work       told          end       hands      white
# 17       view  understand      means         mere      nature     called
# 18       gods        nose       adar          rat        walk     kennel
# 19       atom         god     number        miles        word        man
#
#            19
# 0         fit
# 1    strength
# 2        left
# 3      indian
# 4       heard
# 5       chair
# 6     shadows
# 7       hours
# 8     pointed
# 9       began
# 10     planet
# 11       east
# 12  furniture
# 13       pack
# 14   carvings
# 15     murder
# 16    thought
# 17    present
# 18    kitchen
# 19    gravity

# %%
'''import numpy as np

num_topics = 20

doc_name = []

for label in doc_labels:
    l = label.split("/")[1]
    l = l.split("_")[1]
    l = l.split(".")[0]
    doc_name.append(l)

# turn this into an array so we can use NumPy functions
novel_names = np.asarray(doc_name)
print(novel_names[:5])

doctopic_orig = doctopicsMatrix.copy()

# use method described in preprocessing section
num_groups = len(set(novel_names))
#print(num_groups)

doctopic_grouped = np.zeros((num_groups, num_topics))

for i, name in enumerate(set(novel_names)):
    doctopic_grouped[i, :] = np.mean(doctopicsMatrix[novel_names == name, :], axis=0)

doctopicsMatrix = doctopic_grouped'''
# Out:
# 'import numpy as np\n\nnum_topics = 20\n\ndoc_name = []\n\nfor label in doc_labels:\n    l = label.split("/")[1]\n    l = l.split("_")[1]\n    l = l.split(".")[0]\n    doc_name.append(l)\n\n# turn this into an array so we can use NumPy functions\nnovel_names = np.asarray(doc_name)\nprint(novel_names[:5])\n\ndoctopic_orig = doctopicsMatrix.copy()\n\n# use method described in preprocessing section\nnum_groups = len(set(novel_names))\n#print(num_groups)\n\ndoctopic_grouped = np.zeros((num_groups, num_topics))\n\nfor i, name in enumerate(set(novel_names)):\n    doctopic_grouped[i, :] = np.mean(doctopicsMatrix[novel_names == name, :], axis=0)\n\ndoctopicsMatrix = doctopic_grouped'

# %%
'''doctopicDF.index = [doc2id[x] for x in range(1, len(doc2id) +1 )]
doctopicDFR = pd.DataFrame(doctopicsMatrix)
'''
# Out:
# 'doctopicDF.index = [doc2id[x] for x in range(1, len(doc2id) +1 )]\ndoctopicDFR = pd.DataFrame(doctopicsMatrix)\n'

# %%
'''# !/usr/bin/env python3
# Filename: mallet2wordle.py

"""
# Transform MALLET output for visualization with wordle.net.
"""


#########################
# Remarks
#########################

# Takes as input the MALLET output file containing rows of topic, word, weight information.
# You will have to ask MALLET to output this file using the "--topic-word-weights-file FILENAME" option.
# Produces as output a plain text file containing, for each topic, the top-100 words with their relative score.
# Paste this output, for the topic you are interested in, into the "advanced" wordle page: http://www.wordle.net/advanced
# This script will work best with Python3. You need to have numpy and pandas installed.
# The sample file included in the toolbox repo comes from a collection of 376 French plays from theatre-classique.fr.


#########################
# Import statements
#########################

import numpy as np
import itertools
import operator
import os
import pandas as pd
from collections import Counter

def mallet2wordle(infile,outfile):
    """Transform MALLET output for visualization with wordle.net."""
    ### Load the data from MALLET.
    word_scores = pd.read_table(infile, header=None, sep="\t")
    word_scores = word_scores.sort(columns=[0,2], axis=0, ascending=[True, False])
    word_scores_grouped = word_scores.groupby(0)
    number_of_topics = len(word_scores.groupby(0).size())

    ### For each topic, find the top-100 words with their scores.
    top_topic_words_with_scores = ""
    for i in range(0,number_of_topics-1):
        topic_word_scores = word_scores_grouped.get_group(i)
        top_topic_word_scores = topic_word_scores.iloc[0:100]
        topic_words = top_topic_word_scores.loc[:,1].tolist()
        word_scores = top_topic_word_scores.loc[:,2].tolist()

        top_topic_words_with_scores = top_topic_words_with_scores + "tp" + str(i) + "\n"
        j = 0
        for word in topic_words:
            score = word_scores[j]
            j += 1
            line = word + ":" + str(int(score)) + "\n"
            top_topic_words_with_scores = top_topic_words_with_scores + line
        top_topic_words_with_scores = top_topic_words_with_scores + "\n"
    with open(outfile, "w") as outfile:
        outfile.write(top_topic_words_with_scores)'''
# Out:
# '# !/usr/bin/env python3\n# Filename: mallet2wordle.py\n\n"""\n# Transform MALLET output for visualization with wordle.net.\n"""\n\n\n#########################\n# Remarks\n#########################\n\n# Takes as input the MALLET output file containing rows of topic, word, weight information.\n# You will have to ask MALLET to output this file using the "--topic-word-weights-file FILENAME" option.\n# Produces as output a plain text file containing, for each topic, the top-100 words with their relative score.\n# Paste this output, for the topic you are interested in, into the "advanced" wordle page: http://www.wordle.net/advanced\n# This script will work best with Python3. You need to have numpy and pandas installed.\n# The sample file included in the toolbox repo comes from a collection of 376 French plays from theatre-classique.fr.\n\n\n#########################\n# Import statements\n#########################\n\nimport numpy as np\nimport itertools\nimport operator\nimport os\nimport pandas as pd\nfrom collections import Counter\n\ndef mallet2wordle(infile,outfile):\n    """Transform MALLET output for visualization with wordle.net."""\n    ### Load the data from MALLET.\n    word_scores = pd.read_table(infile, header=None, sep="\t")\n    word_scores = word_scores.sort(columns=[0,2], axis=0, ascending=[True, False])\n    word_scores_grouped = word_scores.groupby(0)\n    number_of_topics = len(word_scores.groupby(0).size())\n\n    ### For each topic, find the top-100 words with their scores.\n    top_topic_words_with_scores = ""\n    for i in range(0,number_of_topics-1):\n        topic_word_scores = word_scores_grouped.get_group(i)\n        top_topic_word_scores = topic_word_scores.iloc[0:100]\n        topic_words = top_topic_word_scores.loc[:,1].tolist()\n        word_scores = top_topic_word_scores.loc[:,2].tolist()\n\n        top_topic_words_with_scores = top_topic_words_with_scores + "tp" + str(i) + "\n"\n        j = 0\n        for word in topic_words:\n            score = word_scores[j]\n            j += 1\n            line = word + ":" + str(int(score)) + "\n"\n            top_topic_words_with_scores = top_topic_words_with_scores + line\n        top_topic_words_with_scores = top_topic_words_with_scores + "\n"\n    with open(outfile, "w") as outfile:\n        outfile.write(top_topic_words_with_scores)'

# %%
'''basepath = os.path.join(os.path.abspath('.'), "tutorial_supplementals/mallet_output")
print(basepath)
infile = os.path.join(basepath,"topic-word-weights.txt")
infile = "/home/sina/Uni/Dariah/DARIAH-Topics/Topics/tutorial_supplementals/mallet_output/topic-word-weights.txt"
print(infile)
outfile = os.path.join(basepath, "wordle.txt")
mallet2wordle(infile,outfile)'''
# Out:
# 'basepath = os.path.join(os.path.abspath(\'.\'), "tutorial_supplementals/mallet_output")\nprint(basepath)\ninfile = os.path.join(basepath,"topic-word-weights.txt")\ninfile = "/home/sina/Uni/Dariah/DARIAH-Topics/Topics/tutorial_supplementals/mallet_output/topic-word-weights.txt"\nprint(infile)\noutfile = os.path.join(basepath, "wordle.txt")\nmallet2wordle(infile,outfile)'

# %% [markdown]
# ![success](http://cdn2.hubspot.net/hub/128506/file-446943132-jpg/images/computer_woman_success.jpg)
