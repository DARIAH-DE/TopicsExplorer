# %%
from dariah_topics import preprocessing as pre
from dariah_topics import visualization as visual
from dariah_topics import evaluation

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# #### Liste mit Dateinamen erzeugen

# %%
path_txt = "corpus_txt"
#path_txt = "grenzbote_plain/*/"
#path_txt = "wiki/"

doclist_txt = pre.create_document_list(path_txt)
assert doclist_txt, "No documents found"
doclist_txt[:5]
# Out:
# INFO preprocessing: Creating document list from TXT files ...
# ['corpus_txt/Lovecraft_AttheMountainofMadness.txt',
#  'corpus_txt/Howard_TheDevilinIron.txt',
#  'corpus_txt/Poe_ThePurloinedLetter.txt',
#  'corpus_txt/Lovecraft_TheShunnedHouse.txt',
#  'corpus_txt/Poe_TheMasqueoftheRedDeath.txt']

# %% [markdown]
# #####  Liste mit Dokumentenlabels erzeugen - (Funktion wird durch Thorsten's generischere Funktion ersetzt)

# %%
doc_labels = list(pre.get_labels(doclist_txt))
doc_labels[:5]
# Out:
# INFO preprocessing: Creating document labels ...
# ['Lovecraft_AttheMountainofMadness',
#  'Howard_TheDevilinIron',
#  'Poe_ThePurloinedLetter',
#  'Lovecraft_TheShunnedHouse',
#  'Poe_TheMasqueoftheRedDeath']

# %% [markdown]
# #### Corpus laden

# %%
corpus_txt = pre.read_from_txt(doclist_txt)

# %% [markdown]
# #### Segmentieren

# %%
segments = pre.segment(corpus_txt, 1000)
segments
# Out:
# <generator object segment_fuzzy at 0x7f77c36095c8>

# %% [markdown]
# #### Tokenisieren

# %%
doc_tokens = [list(pre.tokenize(txt)) for txt in list(corpus_txt)]
# Out:
# INFO preprocessing: Accessing TXT documents ...

# %% [markdown]
# #### Create Dictionaries

# %%
id_types = pre.create_dictionary(doc_tokens)
doc_ids = pre.create_dictionary(doc_labels)
id_types
# Out:
# {'afeared': 1,
#  'hones': 4198,
#  'men-folk': 2,
#  'shuts': 4,
#  'slaty-blue': 5,
#  'creep': 6,
#  'feat': 7,
#  'brumby': 10,
#  'muscled': 11,
#  'ax': 12,
#  'mention': 13,
#  'finger-tips': 14,
#  'sloppy': 11143,
#  'calf': 16,
#  'rascals': 17,
#  'formless': 11142,
#  'beast': 18,
#  'stone-still': 19,
#  'pyramids': 21,
#  'globe': 22,
#  'datum': 23,
#  'donna': 24,
#  'saddles': 25,
#  'indulged': 26,
#  'convolvuluses': 27,
#  'fitful': 28,
#  'unhurt': 29,
#  'ugh': 30,
#  'scandalous': 31,
#  'wented-past': 32,
#  'tinted': 33,
#  'sill': 34,
#  'represented': 18920,
#  'bartholomew': 7413,
#  'jewels': 35,
#  'stenches': 36,
#  'tarry': 37,
#  'dot': 38,
#  'half-luminous': 39,
#  'much-discussed': 40,
#  'fog-wreaths': 41,
#  'acquiring': 42,
#  'starving': 43,
#  'habitual': 44,
#  'uniformly': 45,
#  'ratlook': 48,
#  'abruptness': 47,
#  'employer': 49,
#  'glad': 50,
#  'ran': 51,
#  'satellites': 52,
#  'vapor': 53,
#  'half-strangling': 54,
#  'chemical': 56,
#  'wedding': 57,
#  'selfish': 58,
#  'misfortunes': 59,
#  'tending': 60,
#  'wah': 61,
#  'borders': 62,
#  'visage': 63,
#  'goaded': 64,
#  'chambers': 65,
#  'complex': 7420,
#  'hind-foot': 66,
#  'dial': 67,
#  'black': 68,
#  'spots': 69,
#  'proof': 70,
#  'guiacum': 71,
#  'transcribing': 72,
#  'red-gold': 18638,
#  'supplied': 15,
#  'impassioned': 74,
#  'duplicate': 75,
#  'dunkeln': 76,
#  'chimney': 77,
#  'convulsively': 78,
#  'meditation': 80,
#  'clearances': 81,
#  'preceptor': 9540,
#  'miners': 14279,
#  'yard': 82,
#  'fissure': 83,
#  'presumptuous': 84,
#  'involve': 85,
#  'arulala': 86,
#  'filfy': 87,
#  'fastened': 89,
#  'hydrophobia': 90,
#  'girths-loosed': 91,
#  'foot-fall': 92,
#  'joseph': 93,
#  'unloosed': 94,
#  'vague': 95,
#  'kite': 96,
#  'seize': 97,
#  'village-alive': 3715,
#  'scurry': 98,
#  'taxmen': 100,
#  'sealed': 101,
#  'fully': 14880,
#  'wriggle': 102,
#  'billion': 103,
#  'familiarized': 104,
#  'remain': 105,
#  'clipped': 106,
#  "wulfhere's": 107,
#  'statu': 7426,
#  'holy': 20,
#  'heralded': 108,
#  'accommodate': 109,
#  'discomforted': 11306,
#  'emits': 110,
#  'guardian': 111,
#  'revolutions': 112,
#  'antecedents': 113,
#  'effusion': 115,
#  'champed': 116,
#  'favorable': 117,
#  'crossroads': 119,
#  'faubourg': 120,
#  'atwood': 121,
#  'grossen': 122,
#  'famille': 124,
#  'presently': 125,
#  'vast': 126,
#  'questioners': 127,
#  'calendar': 128,
#  'gravely': 129,
#  'spilt': 3725,
#  'slovenly': 130,
#  'corinthian': 131,
#  'accepted': 132,
#  'flora': 133,
#  'animate': 134,
#  'unfavorable': 135,
#  'biting': 136,
#  'marks': 137,
#  'assortment': 140,
#  'vixen': 141,
#  "argument's": 142,
#  'dick': 143,
#  "shouldn't": 144,
#  'intervals': 145,
#  'lusty': 146,
#  'cold-resistant': 147,
#  'rioting': 148,
#  'directness': 149,
#  'waistcoat': 150,
#  'opposed': 14889,
#  'twined': 151,
#  'motion': 153,
#  'monographs': 157,
#  'patagonia-way': 156,
#  'vertebrae': 158,
#  'fairy': 159,
#  'fetching': 160,
#  'solchen': 162,
#  'abou': 163,
#  'refusal': 164,
#  'ranchman': 18652,
#  'ambiguity': 165,
#  'sojourn': 3733,
#  'dis': 166,
#  'biting-out': 167,
#  'long-horned': 168,
#  'surge': 169,
#  'straight-walking': 170,
#  'harmony': 171,
#  'counterbalance': 172,
#  'romped': 173,
#  'telling': 174,
#  'friendless': 175,
#  'peacefully': 176,
#  'realized': 177,
#  'ale-house': 178,
#  'balustraded': 179,
#  'collar': 11169,
#  'clean-cut': 180,
#  'sings': 181,
#  'donations': 183,
#  'unhad': 184,
#  'jack-in': 185,
#  'panes': 186,
#  'top-coated': 187,
#  'smiths': 188,
#  'pelties': 11174,
#  'rosemary': 189,
#  'ravager-son': 18658,
#  "drebber's": 190,
#  'fellow-atom': 3737,
#  'lengths': 191,
#  'bland': 192,
#  'latterly': 193,
#  'deception': 194,
#  'killer-whale': 195,
#  'rock': 7298,
#  'proclaimed': 196,
#  'coughed': 197,
#  'islands': 198,
#  'violin-playing': 199,
#  'picked': 200,
#  'radicalness': 201,
#  "she'll": 203,
#  'ouch': 204,
#  'dancer': 208,
#  'lovies': 206,
#  'hotfoot': 209,
#  'sicked-up': 7445,
#  'offices': 210,
#  'yearling': 211,
#  'michaelmas': 212,
#  'slipped': 14896,
#  'fireside': 18663,
#  'outbreak': 213,
#  'liver': 214,
#  'savages': 215,
#  'all-of': 216,
#  'remarkable-looking': 217,
#  'wincing': 218,
#  'sleeped': 219,
#  'sadness': 220,
#  'fortunes': 7096,
#  'democracy': 221,
#  'bending': 222,
#  'goods': 223,
#  'glut': 224,
#  'foulmire': 228,
#  "i'll": 227,
#  'insidious': 229,
#  'gaelic': 230,
#  'mutterings': 231,
#  'array': 232,
#  'mesh-mail': 233,
#  'residence': 234,
#  'ac': 235,
#  'made': 236,
#  'somewhere': 237,
#  'spade': 14899,
#  'prearranged': 238,
#  'rang': 239,
#  'triassic': 240,
#  'measuring': 241,
#  'dauntless': 242,
#  'plantation': 245,
#  'bluish': 244,
#  'shore-line': 18670,
#  'lunge': 246,
#  'gedney': 248,
#  'drooped': 249,
#  'standing': 251,
#  'kingdoms': 252,
#  "woodcutter's": 253,
#  'glass-topped': 254,
#  'destruction': 255,
#  'soundlessly': 256,
#  'expired': 259,
#  'red-sashed': 260,
#  'theories': 261,
#  'appeasing': 46,
#  'resident': 262,
#  'mongrels': 263,
#  'showman': 264,
#  'increases': 14902,
#  'leader': 265,
#  "you're": 266,
#  'die': 267,
#  'listens': 268,
#  'lucid': 269,
#  'draw': 271,
#  'fringe': 272,
#  'recapture': 273,
#  'complimented': 274,
#  'highclass': 275,
#  'amber-and': 276,
#  'darkened': 277,
#  'phenomena': 278,
#  'solving': 279,
#  'spectrally': 280,
#  'rendered': 281,
#  "friend's": 282,
#  'owls': 3754,
#  'hen-killer': 284,
#  'self-cognizance': 286,
#  'deride': 18675,
#  'eggy': 287,
#  'cul-de': 3756,
#  'imposed': 288,
#  'tar': 290,
#  'despotism': 292,
#  'depicted': 293,
#  'unaccountability': 18676,
#  'skilful': 295,
#  'turn': 296,
#  'smart': 297,
#  'sorrowfully': 13396,
#  'tendo': 298,
#  'operated': 299,
#  'finish': 300,
#  'drillings': 301,
#  'climates': 303,
#  'ghastly': 304,
#  'labors': 305,
#  'four-wheeler': 307,
#  'leer': 308,
#  "papa's": 310,
#  'opportunities': 311,
#  'pterodactyl': 312,
#  'laughing': 313,
#  'population': 18679,
#  'giant': 55,
#  'fore-and': 314,
#  'oranges': 18682,
#  "fellow's": 315,
#  'wired': 316,
#  'kadath': 317,
#  'damper': 318,
#  'neglect': 320,
#  'mired': 322,
#  'cuttings': 323,
#  'damp': 325,
#  'stool': 326,
#  'point': 327,
#  'betrothal': 328,
#  'placed': 329,
#  'ungraciously': 11194,
#  'waddled': 330,
#  'hand': 331,
#  'kamya': 333,
#  "rope's": 335,
#  'mealy-mouthed': 334,
#  'conjure': 336,
#  'imaginable': 337,
#  'floodtime': 339,
#  'dant': 340,
#  'ulysses': 341,
#  'grizzled': 342,
#  'correct': 343,
#  'bet': 344,
#  'disciples': 345,
#  'amazed': 347,
#  'shes': 348,
#  'vehemence': 349,
#  'ceasing': 350,
#  'corps': 351,
#  'dost': 352,
#  'afterward': 353,
#  'breezes': 354,
#  'seal-skin': 355,
#  'villainy': 356,
#  'surgeon': 357,
#  'overlook': 358,
#  'metaphysical': 359,
#  'cöalitions': 360,
#  'unlighted': 361,
#  'montresor': 362,
#  'laborious': 363,
#  'life-boat': 365,
#  'habitat': 366,
#  'slush': 367,
#  'vista': 368,
#  'piquancy': 11200,
#  'township': 369,
#  'trincomalee': 370,
#  'coffin-lid': 371,
#  'needless': 372,
#  'dash-fine': 373,
#  'parties': 374,
#  'rikk-tck': 375,
#  'symmetry': 6420,
#  'troubles': 377,
#  'view': 378,
#  'conceded': 379,
#  'cross-examined': 380,
#  'rebuttoned': 15782,
#  'believed': 381,
#  'extinct': 382,
#  'crowning': 383,
#  'acquired': 384,
#  'celibate': 14915,
#  'specification': 385,
#  'jessamine': 386,
#  'antiquated': 387,
#  "cmb's": 388,
#  'historical': 389,
#  'sleepest': 390,
#  'face': 11206,
#  'maddest': 392,
#  'accessory': 393,
#  'twig': 394,
#  'portray': 395,
#  'nearness': 397,
#  'successful': 399,
#  'jumps': 400,
#  'waste-paper': 402,
#  'ware-chicken': 403,
#  'romeo': 404,
#  'vices': 405,
#  'dogmaticians': 406,
#  'vast-enough': 407,
#  'warranted': 408,
#  'brute': 409,
#  'unreached': 410,
#  'gash': 412,
#  'acme': 413,
#  'sleep-in': 414,
#  'sprig': 11211,
#  'travels': 416,
#  'sheering': 417,
#  'freeboard': 418,
#  'truncated': 419,
#  'pump': 420,
#  'transcriber': 14921,
#  'sloop': 421,
#  'substantial': 422,
#  "hutchinson's": 423,
#  'troop': 11857,
#  'rawal': 424,
#  'undo': 425,
#  'deserting': 426,
#  'critically': 427,
#  'streams': 428,
#  'mutual': 429,
#  'splits': 430,
#  'reporting': 431,
#  'strait-jacket': 432,
#  'canyons': 433,
#  'terrace': 434,
#  'recuperation': 435,
#  'flatter': 437,
#  'stock-undoubtedly': 438,
#  'dismal': 439,
#  'reeving': 440,
#  'particles': 441,
#  'refined': 442,
#  'entrance': 444,
#  'german-speaking': 445,
#  'facts': 446,
#  'towered': 447,
#  'malignant': 448,
#  'packing': 449,
#  'conceived': 450,
#  'sally': 452,
#  'unhealthy': 73,
#  'hangs': 453,
#  'strenuous': 455,
#  'train': 457,
#  'downward': 458,
#  'omniscience': 459,
#  'groping': 460,
#  'enabled': 8890,
#  'corridor': 461,
#  'chair': 463,
#  'dissent': 464,
#  'frenzy': 465,
#  'hinted': 466,
#  'assure': 467,
#  'unfrequently': 468,
#  'translucent': 469,
#  'smoke-rocket': 470,
#  'four-wheeled': 471,
#  'manservant': 472,
#  'thumb-mark': 474,
#  'impassable': 475,
#  'processes': 476,
#  "day's": 477,
#  'brooch': 478,
#  'co': 479,
#  'lover': 481,
#  'pronounce': 79,
#  'ordinance': 14933,
#  'magnificent': 482,
#  'structures': 485,
#  'penang': 486,
#  'analogous': 487,
#  'coward': 14936,
#  'prevails': 488,
#  'abyssward': 18710,
#  'decadence': 490,
#  'occurred': 493,
#  'ample': 494,
#  'semaphoring': 495,
#  'alibi': 496,
#  'graves': 497,
#  'unaccounted': 499,
#  'lamentable': 502,
#  'cigar': 501,
#  'dairy': 503,
#  "arm's": 3257,
#  'look-see': 504,
#  'likes': 505,
#  'wooden-legged': 506,
#  'chuchundra': 507,
#  'wharfingers': 508,
#  'peaky': 509,
#  'general': 510,
#  'extensive': 511,
#  'boy': 512,
#  'thinness': 513,
#  'normality': 514,
#  'folklorist': 515,
#  'beyondness': 516,
#  'hamjuice': 517,
#  'water-pipe': 11226,
#  'dissolving': 14943,
#  'third': 518,
#  'reports': 519,
#  'breakfast': 520,
#  'blinked': 521,
#  'argue': 522,
#  'raj': 523,
#  'man-pack': 527,
#  'lying': 529,
#  'contributed': 530,
#  'austere': 531,
#  'hollows': 3795,
#  'omit': 3791,
#  'gas': 533,
#  'pedlar': 534,
#  'yacht': 535,
#  'venerable': 536,
#  'gallop': 538,
#  'fox': 3796,
#  'mutilated': 539,
#  'hereby': 540,
#  'invaders': 541,
#  'hatched': 542,
#  'pseudofoot': 543,
#  'over-exposure': 544,
#  'plots': 545,
#  'notified': 546,
#  'accounted': 3131,
#  'jim': 548,
#  'elephant-folk': 549,
#  'mahomet': 550,
#  'peasants': 551,
#  'finesse': 552,
#  'leadership': 553,
#  'tree-tops': 554,
#  'load': 555,
#  'heavily': 556,
#  'pierril': 557,
#  'labouring': 1440,
#  'suspicious': 558,
#  'smallness': 559,
#  'precautions': 560,
#  'stamp': 7496,
#  'gravitating': 561,
#  'engine-room': 562,
#  'follows': 563,
#  'tiller': 565,
#  'day-and': 567,
#  'stacked': 568,
#  'clothe': 3803,
#  'well-set': 12273,
#  'poncho': 99,
#  'all-us': 570,
#  'generally': 571,
#  'cities': 572,
#  'diminishes': 574,
#  'fear': 18632,
#  'jowels': 575,
#  'dies': 576,
#  'either': 577,
#  'hardness': 578,
#  'avenue': 579,
#  'velvet-lined': 581,
#  'late-built': 583,
#  "fritz's": 586,
#  'certainty': 588,
#  'impede': 587,
#  'outpouring': 10219,
#  'commit': 589,
#  'untied': 590,
#  'rushes': 591,
#  "we've": 592,
#  'athelney': 594,
#  'templed': 595,
#  'challenges': 596,
#  'busily': 598,
#  'typewriter': 601,
#  'unkennel': 599,
#  'bohème': 600,
#  'warder': 602,
#  'married': 7501,
#  'jarred': 603,
#  'thoroughness': 604,
#  'attempting': 605,
#  'conceive': 606,
#  'waterproof': 607,
#  'openness': 608,
#  'bitterns': 611,
#  'honours': 612,
#  'wildest': 613,
#  'detestable': 614,
#  'unbosomed': 617,
#  'quarry': 616,
#  'gaze': 618,
#  'whom': 619,
#  'strolled': 620,
#  "moulton's": 622,
#  'babies': 623,
#  'dwarfing': 624,
#  'equestrian': 626,
#  'recruit-mule': 629,
#  'knifing': 628,
#  'downs': 9303,
#  'coping': 630,
#  'determined': 631,
#  'engulfed': 7724,
#  'quills': 19589,
#  'ripen': 632,
#  'reiterated': 633,
#  'ought': 634,
#  'reproducing': 635,
#  'evidently': 636,
#  'but': 637,
#  'dream-land': 638,
#  'confirming': 639,
#  'colossally': 640,
#  'unbecomingly': 641,
#  'sallow': 11247,
#  'inn': 642,
#  'coarseness': 643,
#  'augment': 644,
#  'signed': 645,
#  'hatred': 646,
#  'corrientes': 3818,
#  'guts-of': 11029,
#  'amplified': 647,
#  'jingled': 648,
#  'pure': 649,
#  'dam-all': 650,
#  'recurrence': 651,
#  'partook': 652,
#  'jumping-on': 22204,
#  'produce': 653,
#  'louder': 654,
#  'plagues': 655,
#  'pertinaciously': 660,
#  'eg': 658,
#  'crawls': 114,
#  'rivals': 3820,
#  'approaching': 661,
#  'moidores': 18738,
#  'deep': 663,
#  'delude': 664,
#  'difficulties': 665,
#  'cöexist': 666,
#  'thus': 667,
#  'asked': 668,
#  'brunette': 670,
#  'braces': 671,
#  'extent': 672,
#  'traditional': 673,
#  'elucidate': 674,
#  'want': 11250,
#  'designs': 675,
#  'insidiously': 11252,
#  'outwards': 676,
#  'tribal': 677,
#  'believers': 7506,
#  'dusty-looking': 678,
#  'secreting': 679,
#  'sleep-hunting': 7860,
#  'wanting': 682,
#  'calmness': 683,
#  'dollies': 684,
#  'months': 685,
#  'grading': 686,
#  'far-off': 689,
#  'scribbled': 688,
#  'mineral': 691,
#  'coiled': 692,
#  'harsh': 11459,
#  'intuition': 693,
#  'imperfectly': 694,
#  'bearded': 695,
#  'forbade': 7511,
#  'wrote': 696,
#  'soles': 697,
#  'sex': 698,
#  'rend': 699,
#  'kepler': 701,
#  'larsen': 703,
#  'self-slaughter': 702,
#  'pistols': 18743,
#  'safest': 704,
#  'arranged': 705,
#  'undertook': 708,
#  'disconcert': 709,
#  'disconsolate': 710,
#  'trial': 711,
#  'galaxy': 712,
#  'dislodged': 7516,
#  'prowling': 713,
#  'silences': 714,
#  'survived': 715,
#  'hardship': 716,
#  'landslide': 717,
#  'barrelled': 718,
#  'heh': 11257,
#  'accursed': 6845,
#  'swings': 7517,
#  'listenin': 725,
#  'khorala': 724,
#  'swish': 721,
#  'burrowed': 722,
#  'heated': 723,
#  'kya-a': 726,
#  'bogie': 727,
#  'murderous': 118,
#  'tree-roads': 728,
#  'frankly': 729,
#  'heart-subduing': 730,
#  'fellow-mortal': 731,
#  'flotilla': 732,
#  'wildness': 1475,
#  'flaxen': 733,
#  'sailor': 734,
#  'tools': 737,
#  'mound-heaps': 738,
#  'sermon': 14968,
#  'avidly': 739,
#  'inaccessible': 740,
#  'snibbed': 741,
#  'stoopids': 742,
#  'joint': 743,
#  'gelatinous': 744,
#  'disperse': 747,
#  'distended': 746,
#  'asthmatic': 748,
#  'ubiquitous': 749,
#  'importunate': 750,
#  'bittern': 123,
#  'gagged': 751,
#  'bleaker': 7523,
#  'buttered': 752,
#  'challenge': 753,
#  'informant': 754,
#  'serving': 755,
#  'ramifications': 756,
#  'regularity': 11263,
#  'bemused': 757,
#  'mogul': 758,
#  'perceptibly': 759,
#  'plot': 760,
#  'fro': 761,
#  'vacillating': 762,
#  'puddling': 763,
#  'last-run': 765,
#  'skulk': 766,
#  'prettily': 769,
#  'speckled': 770,
#  'lullaby': 771,
#  'wilful': 772,
#  'resort': 773,
#  'replacing': 774,
#  'vines': 776,
#  'australia': 778,
#  'immensity': 779,
#  'scrutiny': 780,
#  'entering': 18756,
#  'fiendishness': 782,
#  'landing-parties': 783,
#  'dissolve': 784,
#  'third-rate': 786,
#  'gateway': 787,
#  'seventeenth': 788,
#  'ib': 789,
#  'schoolboy': 790,
#  'hen-ladies': 792,
#  'harp': 793,
#  'fuel-warming': 794,
#  'curve': 795,
#  'parrot': 20801,
#  'daised': 796,
#  'hell-hound': 797,
#  'sounding': 798,
#  'under-the': 799,
#  'prison-officials': 801,
#  'sophistry': 802,
#  'miscarried': 803,
#  'neatly': 804,
#  'complicates': 805,
#  'apologize': 806,
#  'yells': 807,
#  'brown-and': 808,
#  'ophir': 809,
#  'naive': 810,
#  'sombre': 811,
#  'draught': 11274,
#  'miracles': 816,
#  'ireland': 819,
#  'saddlery': 817,
#  'masts': 818,
#  'desisted': 821,
#  'leeds': 822,
#  'imported': 14982,
#  'ice-vapors': 823,
#  'dog-gent': 824,
#  'framed': 825,
#  'reptiles': 827,
#  'flame-eyed': 829,
#  'spurious': 830,
#  'illustrated': 831,
#  'window-pane': 832,
#  'unfair': 833,
#  'happy-dog': 834,
#  'nonsense': 139,
#  'breakfast-table': 835,
#  'heavenly': 836,
#  'livid': 837,
#  'length': 838,
#  'heedlessly': 839,
#  'pitiful': 11280,
#  'l’essence': 14985,
#  'disentangling': 840,
#  'ruddier': 841,
#  'olivia': 843,
#  'dry': 844,
#  'screws': 845,
#  'teachings': 846,
#  'womanly': 847,
#  'bungalow': 848,
#  'inferences': 850,
#  'course': 851,
#  'wooden': 853,
#  'abundant': 854,
#  'panted': 855,
#  'hen': 856,
#  'reconnoitering': 858,
#  'skulking': 859,
#  'teaspoonful': 7610,
#  'cywil': 860,
#  'patch': 861,
#  'night-night': 862,
#  'post': 11287,
#  'spinning-wheels': 863,
#  'dolphin': 865,
#  'luxuries': 11286,
#  'dewanee': 866,
#  'lestrade': 867,
#  'stables': 14994,
#  'enabling': 868,
#  'empress': 869,
#  'rake': 871,
#  'stunned': 10942,
#  'flare': 872,
#  "d'or": 10157,
#  'disturb': 873,
#  'navigation': 874,
#  'shown': 3859,
#  'seafaring': 875,
#  'petulant': 876,
#  'foci': 878,
#  'forty-seven': 879,
#  'protracted': 881,
#  'binder': 882,
#  'bier': 883,
#  'field': 884,
#  'cracked': 885,
#  'hug': 886,
#  'sailing-orders': 888,
#  'regent': 889,
#  'thereafter': 890,
#  'overhanging': 10484,
#  'pounded': 891,
#  'sleepless': 7542,
#  'intelligently': 892,
#  "servant's": 152,
#  'lunching': 893,
#  'fatigue': 894,
#  'scrambled': 895,
#  'equals': 896,
#  'art-product': 897,
#  'rubbery': 898,
#  'planes': 13613,
#  'spur': 899,
#  'projecting': 900,
#  'well-trained': 901,
#  'amended': 154,
#  'unpleasing': 902,
#  'devil-worshippers': 903,
#  'enterprise': 904,
#  'provision': 905,
#  'prospero': 907,
#  'stroll': 908,
#  'sciences': 155,
#  'attainable': 21325,
#  'market': 909,
#  'silhouetted': 910,
#  'reinforcing': 911,
#  'words': 912,
#  'himthenshe': 913,
#  'chucking': 3866,
#  'end-notes': 914,
#  'bunsen': 916,
#  'impresses': 919,
#  'hand-trolley': 918,
#  'visiting-cards': 920,
#  'kissed': 922,
#  'lets': 923,
#  'parrot-mouthed': 925,
#  'skug-cur': 926,
#  'dash-quick': 927,
#  'crucial': 928,
#  'biasing': 929,
#  'broken-off': 931,
#  'landed': 932,
#  'volcanism': 933,
#  'craned': 934,
#  "week's": 161,
#  'toby': 936,
#  'good-sized': 138,
#  'winking': 937,
#  'conversations': 939,
#  'though': 940,
#  'schade': 942,
#  'vary': 943,
#  'extirpating': 944,
#  "vision's": 945,
#  'which': 946,
#  'hindering': 947,
#  'hard-faced': 948,
#  'tremor': 949,
#  'drug': 951,
#  'nails': 952,
#  'discovering': 953,
#  'influences': 955,
#  'psychologists': 956,
#  'flaunting': 957,
#  'revealed': 958,
#  'they-think': 959,
#  'eruption': 960,
#  'age-blackened': 962,
#  'affrightedly': 963,
#  'pickman': 3877,
#  'temperance': 18786,
#  'confused': 964,
#  'climbed': 967,
#  'herding': 18789,
#  'flat-roofed': 968,
#  'toadstools': 969,
#  'nursed': 970,
#  'greenish': 971,
#  'cabinet': 972,
#  'perpetrate': 973,
#  'smiles': 974,
#  'principle’s': 975,
#  'thoughtful': 977,
#  'smiling': 978,
#  'apedom': 979,
#  'agape': 980,
#  'guyed': 11311,
#  'burglaries': 983,
#  'sardonicus': 984,
#  'efficient': 986,
#  "bachelor's": 987,
#  'inequidistant': 988,
#  'lore': 989,
#  'ferrets': 990,
#  'scholar': 991,
#  'plenty-lots': 992,
#  'dovetailed': 993,
#  'obtain': 994,
#  'hoot': 995,
#  'robust': 996,
#  'endearment': 998,
#  'grew': 999,
#  'water-snake': 1000,
#  'indorse': 1001,
#  'individuality': 1002,
#  'well-grown': 1003,
#  'over-profound': 1004,
#  'genuine': 1005,
#  'connexion': 1006,
#  'leaned': 1007,
#  'chronicle': 1008,
#  'sustained': 1009,
#  'tanning': 1010,
#  'spending': 9693,
#  'goner': 8620,
#  'wiles': 1011,
#  'stars': 1012,
#  'hedge': 1013,
#  'youngest': 1014,
#  'snaps': 1015,
#  'shivering': 1016,
#  'exhalation': 1017,
#  'raided': 1018,
#  'applauding': 1019,
#  'augmented': 1020,
#  "tonga's": 1022,
#  'im-which': 1023,
#  'reddish': 1024,
#  'devoured': 1025,
#  "tent's": 1026,
#  'leg-weary': 1027,
#  ...}

# %% [markdown]
# #### Sparse BOW Model

# %%
sparse_bow = pre.create_sparse_bow(doc_labels, doc_tokens, id_types, doc_ids)

# %%
sparse_bow
# Out:
#                   0
# doc_id token_id
# 1      13639      2
#        8195       1
#        16388      1
#        6          1
#        12289      1
#        16392      1
#        9          1
#        5463       1
#        8204       1
#        16397      1
#        8206       1
#        8207       3
#        8208       1
#        18         2
#        16407      1
#        16409      1
#        8219       1
#        16413      1
#        16414      5
#        32         1
#        10928      1
#        16418     15
#        16419      2
#        9565       1
#        48         1
#        16433      1
#        50         4
#        51        27
#        19642      1
#        16440     19
# ...              ..
# 17     16300      1
#        16301      8
#        16303      3
#        16305      5
#        16307      1
#        16308      5
#        16321      2
#        16323      2
#        16324      1
#        16374      1
#        16333      2
#        16336      1
#        16339      2
#        16340      1
#        16342     11
#        16343      1
#        16344      1
#        16346      1
#        16350      1
#        21840     20
#        16357      2
#        16358      5
#        16360      1
#        16361     16
#        16362      1
#        4364       2
#        16377      1
#        16378      4
#        16383      4
#        5461       1
#
# [56639 rows x 1 columns]

# %% [markdown]
# ## Topic Modeling with Gensim

# %% [markdown]
# ##### Saving Sparse BOW

# %%
pre.save_sparse_bow(sparse_bow, "gensim_txt")

# %% [markdown]
# #### Import Market Matrix

# %%
from gensim.models import LdaModel
from gensim.corpora import MmCorpus
from gensim.corpora import SvmLightCorpus
# Out:
# INFO summa.preprocessing.cleaner: 'pattern' package not found; tag filters are not available for English

# %%
mm = MmCorpus("gensim_txt.mm")
# Out:
# INFO gensim.matutils: initializing corpus reader from gensim_txt.mm
# INFO gensim.matutils: accepted corpus with 17 documents, 22232 features, 369906 non-zero entries

# %%
corpus = MmCorpus('gensim_txt.mm')
SvmLightCorpus.serialize('corpus.svmlight', corpus)
# Out:
# INFO gensim.matutils: initializing corpus reader from gensim_txt.mm
# INFO gensim.matutils: accepted corpus with 17 documents, 22232 features, 369906 non-zero entries
# INFO gensim.corpora.svmlightcorpus: converting corpus to SVMlight format: corpus.svmlight
# INFO gensim.corpora.indexedcorpus: saving SvmLightCorpus index to corpus.svmlight.index

# %%
doc2id = {value : key for key, value in doc_ids.items()}
type2id = {value : key for key, value in id_types.items()}

# %% [markdown]
# ##### Remove Features

# %% [markdown]
# type2id = {value : key for key, value in id_types.items()}
# sparse_bow_collapsed = sparse_bow.groupby(sparse_bow.index.get_level_values('token_id')).sum()

# %% [markdown]
# sparse_bow_hapax = sparse_bow_collapsed.loc[sparse_bow_collapsed[0] == 1]
# hapax = [type2id[key] for key in sparse_bow_hapax.index.get_level_values('token_id')]

# %% [markdown]
# len(hapax)

# %%
import os.path
basepath = os.path.abspath('.')

with open(os.path.join(basepath, "tutorial_supplementals", "stopwords", "de.txt"), 'r', encoding = 'utf-8') as f: 
    stopword_list = f.read().split('\n')
    
stopword_list = set(stopword_list)

# %%
hapax_from_remove = pre.find_hapax(sparse_bow, id_types)
stopwords_from_remove = pre.find_stopwords(sparse_bow, id_types, mfw=75)

#features_to_be_removed = set(hapax_from_remove + stopwords_from_remove)
features_to_be_removed = stopwords_from_remove

sparse_bow_short = pre.remove_features(sparse_bow, id_types, features_to_be_removed)
# Out:
# INFO preprocessing: Finding hapax legomena ...
# INFO preprocessing: Finding stopwords ...
# INFO preprocessing: Removing features ...

# %%
len(features_to_be_removed)
# Out:
# 75

# %%
pre.save_sparse_bow(sparse_bow_short, "gensim_txt")

# %%
mm = MmCorpus("gensim_txt.mm")
# Out:
# INFO gensim.matutils: initializing corpus reader from gensim_txt.mm
# INFO gensim.matutils: accepted corpus with 17 documents, 22232 features, 192053 non-zero entries

# %% [markdown]
# #### Convert sparse_bow to list of (doc, tokens) tuples (like doc2bow)

# %%
doc2bow_list = []

for doc in sparse_bow_short.index.groupby(sparse_bow_short.index.get_level_values('doc_id')):
    temp = [(token, count) for token, count in zip(sparse_bow_short.loc[doc].index, sparse_bow_short.loc[doc][0])]
    doc2bow_list.append(temp)

# %%
doc2bow_list[0]

for
# Out:
# Series([], Name: 0, dtype: int64)

# %%
model = LdaModel(corpus=mm, id2word=type2id, num_topics=20, passes = 10, iterations = 20)
# Out:
# INFO gensim.models.ldamodel: using symmetric alpha at 0.05
# INFO gensim.models.ldamodel: using symmetric eta at 4.49781855799937e-05
# INFO gensim.models.ldamodel: using serial LDA version on this node
# INFO gensim.models.ldamodel: running online LDA training, 20 topics, 10 passes over the supplied corpus of 17 documents, updating model once every 17 documents, evaluating perplexity every 17 documents, iterating 20x with a convergence threshold of 0.001000
# INFO gensim.models.ldamodel: -14.378 per-word bound, 21297.8 perplexity estimate based on a held-out corpus of 17 documents with 192053 words
# INFO gensim.models.ldamodel: PROGRESS: pass 0, at document #17/17
# INFO gensim.models.ldamodel: topic #2 (0.050): 0.003*"wayfarers" + 0.003*"step-daughter" + 0.003*"grouping" + 0.003*"faster" + 0.003*"ape" + 0.003*"frenzied" + 0.003*"spies" + 0.003*"streaked" + 0.003*"loves" + 0.003*"rigging"
# INFO gensim.models.ldamodel: topic #5 (0.050): 0.003*"scuffling" + 0.003*"envisage" + 0.003*"ape" + 0.003*"artistry" + 0.003*"knockin" + 0.003*"frenzied" + 0.003*"born" + 0.003*"grouping" + 0.003*"here" + 0.002*"dispositions"
# INFO gensim.models.ldamodel: topic #7 (0.050): 0.003*"streaked" + 0.003*"envisage" + 0.003*"grouping" + 0.003*"artistry" + 0.003*"frenzied" + 0.003*"wayfarers" + 0.003*"ape" + 0.003*"faster" + 0.003*"concentric" + 0.003*"receives"
# INFO gensim.models.ldamodel: topic #3 (0.050): 0.003*"grouping" + 0.003*"frenzied" + 0.003*"faster" + 0.003*"free-born" + 0.003*"receives" + 0.003*"travelling" + 0.003*"loves" + 0.003*"spies" + 0.002*"leaders" + 0.002*"kneeling"
# INFO gensim.models.ldamodel: topic #14 (0.050): 0.004*"streaked" + 0.003*"scuffling" + 0.003*"knockin" + 0.003*"faster" + 0.003*"fossils" + 0.003*"twinkling" + 0.003*"grouping" + 0.003*"entrusted" + 0.003*"matkah" + 0.003*"ape"
# INFO gensim.models.ldamodel: topic diff=5.872895, rho=1.000000
# INFO gensim.models.ldamodel: -10.937 per-word bound, 1960.7 perplexity estimate based on a held-out corpus of 17 documents with 192053 words
# INFO gensim.models.ldamodel: PROGRESS: pass 1, at document #17/17
# INFO gensim.models.ldamodel: topic #12 (0.050): 0.003*"frenzied" + 0.003*"grouping" + 0.003*"scuffling" + 0.003*"streaked" + 0.003*"born" + 0.003*"blown" + 0.003*"ape" + 0.003*"wayfarers" + 0.003*"ac" + 0.003*"spies"
# INFO gensim.models.ldamodel: topic #5 (0.050): 0.003*"here" + 0.003*"born" + 0.003*"envisage" + 0.003*"knockin" + 0.003*"artistry" + 0.002*"scuffling" + 0.002*"we'll" + 0.002*"ape" + 0.002*"frenzied" + 0.002*"grouping"
# INFO gensim.models.ldamodel: topic #2 (0.050): 0.003*"grouping" + 0.003*"wayfarers" + 0.003*"step-daughter" + 0.003*"frenzied" + 0.003*"faster" + 0.002*"ape" + 0.002*"streaked" + 0.002*"spies" + 0.002*"loves" + 0.002*"versa"
# INFO gensim.models.ldamodel: topic #6 (0.050): 0.005*"caravan" + 0.004*"free-born" + 0.004*"half-sentient" + 0.003*"loves" + 0.003*"envisage" + 0.003*"versa" + 0.003*"spies" + 0.003*"faster" + 0.003*"concentric" + 0.003*"artistry"
# INFO gensim.models.ldamodel: topic #19 (0.050): 0.003*"blown" + 0.003*"scuffling" + 0.003*"knockin" + 0.003*"dome" + 0.003*"free-born" + 0.002*"tripods" + 0.002*"receives" + 0.002*"artistry" + 0.002*"wayfarers" + 0.002*"we'll"
# INFO gensim.models.ldamodel: topic diff=2.620039, rho=0.577350
# INFO gensim.models.ldamodel: -9.721 per-word bound, 843.9 perplexity estimate based on a held-out corpus of 17 documents with 192053 words
# INFO gensim.models.ldamodel: PROGRESS: pass 2, at document #17/17
# INFO gensim.models.ldamodel: topic #18 (0.050): 0.008*"scuffling" + 0.005*"blown" + 0.005*"frenzied" + 0.004*"prominent" + 0.004*"beady" + 0.004*"murderers" + 0.004*"laps" + 0.004*"streaked" + 0.004*"fathomed" + 0.004*"blunted"
# INFO gensim.models.ldamodel: topic #7 (0.050): 0.006*"fossils" + 0.004*"wayfarers" + 0.003*"ape" + 0.003*"artistry" + 0.003*"frenzied" + 0.003*"travelling" + 0.003*"spies" + 0.003*"step-daughter" + 0.003*"envisage" + 0.003*"dome"
# INFO gensim.models.ldamodel: topic #2 (0.050): 0.002*"grouping" + 0.002*"wayfarers" + 0.002*"step-daughter" + 0.002*"frenzied" + 0.002*"faster" + 0.002*"ape" + 0.002*"streaked" + 0.002*"spies" + 0.002*"loves" + 0.002*"versa"
# INFO gensim.models.ldamodel: topic #11 (0.050): 0.009*"paved" + 0.007*"spurs" + 0.006*"envisage" + 0.006*"accumulative" + 0.005*"knockin" + 0.005*"kozaki" + 0.005*"grossest" + 0.005*"we'll" + 0.005*"arms" + 0.004*"artistry"
# INFO gensim.models.ldamodel: topic #16 (0.050): 0.003*"drills" + 0.003*"scuffling" + 0.003*"frenzied" + 0.003*"grouping" + 0.002*"step-daughter" + 0.002*"blown" + 0.002*"knockin" + 0.002*"spies" + 0.002*"swearing" + 0.002*"prominent"
# INFO gensim.models.ldamodel: topic diff=2.145682, rho=0.500000
# INFO gensim.models.ldamodel: -9.232 per-word bound, 601.2 perplexity estimate based on a held-out corpus of 17 documents with 192053 words
# INFO gensim.models.ldamodel: PROGRESS: pass 3, at document #17/17
# INFO gensim.models.ldamodel: topic #11 (0.050): 0.010*"paved" + 0.007*"spurs" + 0.007*"accumulative" + 0.007*"envisage" + 0.006*"knockin" + 0.006*"grossest" + 0.006*"kozaki" + 0.005*"arms" + 0.005*"we'll" + 0.005*"naturalists"
# INFO gensim.models.ldamodel: topic #3 (0.050): 0.002*"grouping" + 0.002*"frenzied" + 0.002*"free-born" + 0.002*"receives" + 0.002*"faster" + 0.002*"scuffling" + 0.002*"travelling" + 0.002*"loves" + 0.002*"leaders" + 0.002*"knockin"
# INFO gensim.models.ldamodel: topic #6 (0.050): 0.006*"caravan" + 0.004*"half-sentient" + 0.004*"free-born" + 0.004*"versa" + 0.004*"artistry" + 0.004*"loves" + 0.004*"wasted" + 0.003*"concentric" + 0.003*"envisage" + 0.003*"commence"
# INFO gensim.models.ldamodel: topic #15 (0.050): 0.007*"akela's" + 0.005*"sick-dog" + 0.005*"se" + 0.003*"magistrate" + 0.003*"streaked" + 0.003*"pooh-pooh" + 0.003*"linked" + 0.003*"scuffling" + 0.003*"thickness" + 0.003*"ports"
# INFO gensim.models.ldamodel: topic #1 (0.050): 0.002*"knockin" + 0.002*"wayfarers" + 0.002*"frenzied" + 0.002*"grouping" + 0.002*"step-daughter" + 0.002*"skirting" + 0.002*"artistry" + 0.001*"streaked" + 0.001*"rigging" + 0.001*"fossils"
# INFO gensim.models.ldamodel: topic diff=1.610747, rho=0.447214
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-09a2fb253791> in <module>()
# ----> 1 model = LdaModel(corpus=mm, id2word=type2id, num_topics=20, passes = 10, iterations = 20)
#
# /home/sina/.local/lib/python3.5/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     332         if corpus is not None:
#     333             use_numpy = self.dispatcher is not None
# --> 334             self.update(corpus, chunks_as_numpy=use_numpy)
#     335
#     336     def init_dir_prior(self, prior, name):
#
# /home/sina/.local/lib/python3.5/site-packages/gensim/models/ldamodel.py in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     633
#     634                 if eval_every and ((reallen == lencorpus) or ((chunk_no + 1) % (eval_every * self.numworkers) == 0)):
# --> 635                     self.log_perplexity(chunk, total_docs=lencorpus)
#     636
#     637                 if self.dispatcher:
#
# /home/sina/.local/lib/python3.5/site-packages/gensim/models/ldamodel.py in log_perplexity(self, chunk, total_docs)
#     524         corpus_words = sum(cnt for document in chunk for _, cnt in document)
#     525         subsample_ratio = 1.0 * total_docs / len(chunk)
# --> 526         perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
#     527         logger.info("%.3f per-word bound, %.1f perplexity estimate based on a held-out corpus of %i documents with %i words" %
#     528                     (perwordbound, np.exp2(-perwordbound), len(chunk), corpus_words))
#
# /home/sina/.local/lib/python3.5/site-packages/gensim/models/ldamodel.py in bound(self, corpus, gamma, subsample_ratio)
#     731
#     732             # E[log p(doc | theta, beta)]
# --> 733             score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, id]) for id, cnt in doc)
#     734
#     735             # E[log p(theta | alpha) - log q(theta | gamma)]; assumes alpha is a vector
#
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1823     """
#    1824     if isinstance(a, _gentype):
# -> 1825         res = _sum_(a)
#    1826         if out is not None:
#    1827             out[...] = res
#
# /home/sina/.local/lib/python3.5/site-packages/gensim/models/ldamodel.py in <genexpr>(.0)
#     731
#     732             # E[log p(doc | theta, beta)]
# --> 733             score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, id]) for id, cnt in doc)
#     734
#     735             # E[log p(theta | alpha) - log q(theta | gamma)]; assumes alpha is a vector
#
# /home/sina/.local/lib/python3.5/site-packages/scipy/special/_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#      90
#      91     """
# ---> 92     a = _asarray_validated(a, check_finite=False)
#      93     if b is not None:
#      94         a, b = np.broadcast_arrays(a,b)
#
# /home/sina/.local/lib/python3.5/site-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     226     """
#     227     if not sparse_ok:
# --> 228         import scipy.sparse
#     229         if scipy.sparse.issparse(a):
#     230             msg = ('Sparse matrices are not supported by this function. '
#
# KeyboardInterrupt:

# %%
model.get_document_topics(doc2bow_list[1])

# %%
#Anzeige der keywords für topic n
n = 1
topic_nr_x = model.get_topic_terms(n)

topicTerms = [type2id[i[0]] for i in topic_nr_x]
topicTerms

# %%
#Topic probabilities - zum Testen der Funktion
topics = model.show_topics(num_topics = model.num_topics, formatted=False)
keywords = []

num_topics = model.num_topics
topics_df = pre.pd.DataFrame(index = range(num_topics), columns= range(10))

for topic, values in topics:
    keyword = [value[0] for value in values]
    topics_df.loc[topic] = keyword

topics_df

# %%
topics_df = pre.gensim2dataframe(model)
topics_df

# %%
doc_topic = topics_df.T
doc_topic

# %% [markdown]
# ## Visualisierung

# %%
'''lda_model = 'out_easy/corpus.lda'
corpus = 'out_easy/corpus.mm'
dictionary = 'out_easy/corpus.dict'
doc_labels = 'out_easy/corpus_doclabels.txt'
interactive  = False

vis = visual.Visualization(lda_model, corpus, dictionary, doc_labels, interactive)'''

# %% [markdown]
# ##### Create a document-topic matrix (that is a pandas data frame actually)

# %%
doc_topic = visual.create_doc_topic(mm, model, doc_labels)

# %% [markdown]
# ##### Visualize document-topic matrix

# %%
# %matplotlib inline
visual.doc_topic_heatmap(doc_topic)

# %% [markdown]
# ##### Visualize topic distribution in a single document

# %%
visual.plot_doc_topics(doc_topic, 0)

# %%
items = model.show_topic(1)
keywords = [item[0] for item in items]
keywords
items = model.show_topic(1)
propabilities = [item[1] for item in items]
propabilities
items

# %%
topic_nr = 3
number_of_keywords = 10
visual.show_wordle_for_topic(model, topic_nr, number_of_keywords)

# %% [markdown]
# ![success](http://cdn2.hubspot.net/hub/128506/file-446943132-jpg/images/computer_woman_success.jpg)
